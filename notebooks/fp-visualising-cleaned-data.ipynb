# %%
from src.features.n_degree_interp import linear_int
import numpy as np
import glob

file_list = glob.glob("../data/interim/labeled" + '/*')
file_list.sort()

# %%
import matplotlib.pyplot as plt

f = file_list[44]

interim_data = np.loadtxt(f, delimiter=',', skiprows=1)
clean_data = linear_int(interim_data[:, 0], interim_data[:, 1])

plt.plot(interim_data[:, 0], interim_data[:, 1])
plt.plot(np.arange(0, 2400), clean_data)
# Out:
# /Users/paissanfrancesco/PycharmProjects/raman_spectrogram_analysis/src/features/n_degree_interp.py:25: RankWarning: Polyfit may be poorly conditioned
#   params = n_ord_interp(x, y)
